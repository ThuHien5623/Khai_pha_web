# %%
import os
import shutil
import nltk
import re
from nltk.probability import FreqDist

filestore = 'D:\Khai_Pha_Web\BTN_C4\Data_Preprocessing'

text_pre = ''
for file in os.listdir(filestore):
  # Đọc nội dung của tệp
    with open(os.path.join(filestore, file), 'r', encoding='utf-8') as f:
        text = f.read()
        text_pre += text

text_pre=nltk.word_tokenize(text_pre) # Tokenizing

print("Number of words: ",len(text_pre))

# Compute the frequency of all words / Tính tần số của tất cả các từ
frequency_dist = FreqDist(word.lower() for word in text_pre)

## show only th top 50 results
print(frequency_dist.most_common(50))

## Consider words with length greater than 3 and plot
# Xem xét các từ có độ dài lớn hơn 3 và vẽ
large_words = dict([(k,v) for k,v in frequency_dist.items() if len(k)>3])
frequency_dist = nltk.FreqDist(large_words)
frequency_dist.plot(50,cumulative=False)
# Out:
# Number of words:  7047
# [('quán', 137), ('ngon', 119), ('i', 113), ('món', 106), ('gọi', 96), ('nhân_viên', 91), ('đi', 78), ('n', 77), ('ng', 65), ('c', 62), ('hơi', 60), ('cơm', 57), ('phục_vụ', 50), ('nh', 49), ('giá', 49), ('đồ_ăn', 46), ('bàn', 40), ('tiền', 39), ('la', 34), ('trà', 33), ('cay', 32), ('gà', 32), ('xong', 30), ('lắm', 30), ('kêu', 30), ('y', 29), ('đồ', 29), ('xe', 28), ('thử', 28), ('chả', 28), ('mi', 28), ('chỗ', 27), ('bánh', 26), ('m', 25), ('uống', 25), ('mấy', 24), ('đc', 24), ('đông', 24), ('thịt', 24), ('thi', 23), ('vị', 23), ('va', 22), ('bình_thường', 22), ('cá', 22), ('lẩu', 22), ('không_gian', 21), ('chờ', 21), ('ly', 21), ('u', 21), ('ok', 20)]
# <Axes: xlabel='Samples', ylabel='Counts'>
